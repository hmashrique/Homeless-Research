# %% [markdown]
# ## SPM data analysis:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read Data:

import pandas as pd

sheet = "2021"
#df = pd.read_excel(file_path, sheet_name=sheet_name)

spm= pd.read_excel("datasets/System-Performance-Measures-Data.xlsx", sheet_name = sheet)

spm.head()
# Out:
#   State                            Continuum of Care (CoC) HUD CoC Number  \
# 0   NaN                                                NaN            NaN
# 1    AK                                      Anchorage CoC         AK-500
# 2    AK                        Alaska Balance of State CoC         AK-501
# 3    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...         AL-500
# 4    AL            Mobile City & County/Baldwin County CoC         AL-501
#
#    2021 CoC Award Amount\n($- indicates that an application was not submitted)  \
# 0                                                NaN
# 1                                          3756917.0
# 2                                           982016.0
# 3                                          9956635.0
# 4                                          4056865.0
#
#   AHAR Part 1 CoC Category                         Bed Coverage  \
# 0                      NaN  Total Non-DV Beds on 2021 HIC ES+TH
# 1  Other Largely Urban CoC                                 1185
# 2        Largely Rural CoC                                  518
# 3     Largely Suburban CoC                                  602
# 4  Other Largely Urban CoC                                  309
#
#                                  Unnamed: 6  \
# 0  Total Non-DV HMIS Beds on 2021 HIC ES+TH
# 1                                      1084
# 2                                       494
# 3                                       464
# 4                                       309
#
#                                           Unnamed: 7             SPM 1  \
# 0  2021 Bed coverage Percent on HMIS for ES-TH Co...  ES-SH Avg (Days)
# 1                                           0.914768                59
# 2                                           0.953668                48
# 3                                           0.770764                56
# 4                                                  1                35
#
#             Unnamed: 9  ...                                Unnamed: 86  \
# 0  ES-SH Median (Days)  ...  HMIS DQ - ES Percent Unknown Destinations
# 1                   20  ...                                   0.831774
# 2                   19  ...                                   0.610868
# 3                   23  ...                                   0.089766
# 4                   11  ...                                   0.016168
#
#                    Unnamed: 87                        Unnamed: 88  \
# 0  HMIS DQ Exits Universe - TH  HMIS DQ Unknown Destinations - TH
# 1                          258                                 49
# 2                          162                                 15
# 3                          131                                  2
# 4                          142                                  3
#
#                                  Unnamed: 89                   Unnamed: 90  \
# 0  HMIS DQ - TH Percent Unknown Destinations  HMIS DQ Exits Universe - RRH
# 1                                   0.189922                           860
# 2                                   0.092593                           196
# 3                                       0.02                           828
# 4                                       0.02                           205
#
#                           Unnamed: 91  \
# 0  HMIS DQ Unknown Destinations - RRH
# 1                                 138
# 2                                   5
# 3                                  40
# 4                                   5
#
#                                   Unnamed: 92                   Unnamed: 93  \
# 0  HMIS DQ - RRH Percent Unknown Destinations  HMIS DQ Exits Universe - PSH
# 1                                    0.160465                           108
# 2                                     0.02551                            35
# 3                                    0.048309                           252
# 4                                     0.02439                            27
#
#                           Unnamed: 94  \
# 0  HMIS DQ Unknown Destinations - PSH
# 1                                   9
# 2                                   3
# 3                                   7
# 4                                   1
#
#                                   Unnamed: 95
# 0  HMIS DQ - PSH Percent Unknown Destinations
# 1                                    0.083333
# 2                                    0.085714
# 3                                        0.03
# 4                                        0.04
#
# [5 rows x 96 columns]

# %%
# Drop the header row
spm.columns = spm.iloc[0]  # Set the first row as header

spm = spm[1:].reset_index(drop=True)  # Drop the first row and reset the index

spm.head()
# Out:
# 0 NaN                                                NaN     NaN        NaN  \
# 0  AK                                      Anchorage CoC  AK-500  3756917.0
# 1  AK                        Alaska Balance of State CoC  AK-501   982016.0
# 2  AL  Birmingham/Jefferson, St. Clair, Shelby Counti...  AL-500  9956635.0
# 3  AL            Mobile City & County/Baldwin County CoC  AL-501  4056865.0
# 4  AL                     Florence/Northwest Alabama CoC  AL-502   452202.0
#
# 0                      NaN Total Non-DV Beds on 2021 HIC ES+TH  \
# 0  Other Largely Urban CoC                                1185
# 1        Largely Rural CoC                                 518
# 2     Largely Suburban CoC                                 602
# 3  Other Largely Urban CoC                                 309
# 4        Largely Rural CoC                                  56
#
# 0 Total Non-DV HMIS Beds on 2021 HIC ES+TH  \
# 0                                     1084
# 1                                      494
# 2                                      464
# 3                                      309
# 4                                        0
#
# 0 2021 Bed coverage Percent on HMIS for ES-TH Combined ES-SH Avg (Days)  \
# 0                                           0.914768                 59
# 1                                           0.953668                 48
# 2                                           0.770764                 56
# 3                                                  1                 35
# 4                                                  0                 49
#
# 0 ES-SH Median (Days)  ... HMIS DQ - ES Percent Unknown Destinations  \
# 0                  20  ...                                  0.831774
# 1                  19  ...                                  0.610868
# 2                  23  ...                                  0.089766
# 3                  11  ...                                  0.016168
# 4                  30  ...                                  0.042424
#
# 0 HMIS DQ Exits Universe - TH HMIS DQ Unknown Destinations - TH  \
# 0                         258                                49
# 1                         162                                15
# 2                         131                                 2
# 3                         142                                 3
# 4                           0                                 0
#
# 0 HMIS DQ - TH Percent Unknown Destinations HMIS DQ Exits Universe - RRH  \
# 0                                  0.189922                          860
# 1                                  0.092593                          196
# 2                                      0.02                          828
# 3                                      0.02                          205
# 4                                       NaN                          172
#
# 0 HMIS DQ Unknown Destinations - RRH  \
# 0                                138
# 1                                  5
# 2                                 40
# 3                                  5
# 4                                  0
#
# 0 HMIS DQ - RRH Percent Unknown Destinations HMIS DQ Exits Universe - PSH  \
# 0                                   0.160465                          108
# 1                                    0.02551                           35
# 2                                   0.048309                          252
# 3                                    0.02439                           27
# 4                                          0                            0
#
# 0 HMIS DQ Unknown Destinations - PSH  \
# 0                                  9
# 1                                  3
# 2                                  7
# 3                                  1
# 4                                  0
#
# 0 HMIS DQ - PSH Percent Unknown Destinations
# 0                                   0.083333
# 1                                   0.085714
# 2                                       0.03
# 3                                       0.04
# 4                                        NaN
#
# [5 rows x 96 columns]

# %%
spm.columns = [
    f"Unnamed_{i}" if pd.isna(col) else col
    for i, col in enumerate(spm.columns, start=1)
]

# %%
spm.head()
# Out:
#   Unnamed_1                                          Unnamed_2 Unnamed_3  \
# 0        AK                                      Anchorage CoC    AK-500
# 1        AK                        Alaska Balance of State CoC    AK-501
# 2        AL  Birmingham/Jefferson, St. Clair, Shelby Counti...    AL-500
# 3        AL            Mobile City & County/Baldwin County CoC    AL-501
# 4        AL                     Florence/Northwest Alabama CoC    AL-502
#
#    Unnamed_4                Unnamed_5 Total Non-DV Beds on 2021 HIC ES+TH  \
# 0  3756917.0  Other Largely Urban CoC                                1185
# 1   982016.0        Largely Rural CoC                                 518
# 2  9956635.0     Largely Suburban CoC                                 602
# 3  4056865.0  Other Largely Urban CoC                                 309
# 4   452202.0        Largely Rural CoC                                  56
#
#   Total Non-DV HMIS Beds on 2021 HIC ES+TH  \
# 0                                     1084
# 1                                      494
# 2                                      464
# 3                                      309
# 4                                        0
#
#   2021 Bed coverage Percent on HMIS for ES-TH Combined ES-SH Avg (Days)  \
# 0                                           0.914768                 59
# 1                                           0.953668                 48
# 2                                           0.770764                 56
# 3                                                  1                 35
# 4                                                  0                 49
#
#   ES-SH Median (Days)  ... HMIS DQ - ES Percent Unknown Destinations  \
# 0                  20  ...                                  0.831774
# 1                  19  ...                                  0.610868
# 2                  23  ...                                  0.089766
# 3                  11  ...                                  0.016168
# 4                  30  ...                                  0.042424
#
#   HMIS DQ Exits Universe - TH HMIS DQ Unknown Destinations - TH  \
# 0                         258                                49
# 1                         162                                15
# 2                         131                                 2
# 3                         142                                 3
# 4                           0                                 0
#
#   HMIS DQ - TH Percent Unknown Destinations HMIS DQ Exits Universe - RRH  \
# 0                                  0.189922                          860
# 1                                  0.092593                          196
# 2                                      0.02                          828
# 3                                      0.02                          205
# 4                                       NaN                          172
#
#   HMIS DQ Unknown Destinations - RRH  \
# 0                                138
# 1                                  5
# 2                                 40
# 3                                  5
# 4                                  0
#
#   HMIS DQ - RRH Percent Unknown Destinations HMIS DQ Exits Universe - PSH  \
# 0                                   0.160465                          108
# 1                                    0.02551                           35
# 2                                   0.048309                          252
# 3                                    0.02439                           27
# 4                                          0                            0
#
#   HMIS DQ Unknown Destinations - PSH  \
# 0                                  9
# 1                                  3
# 2                                  7
# 3                                  1
# 4                                  0
#
#   HMIS DQ - PSH Percent Unknown Destinations
# 0                                   0.083333
# 1                                   0.085714
# 2                                       0.03
# 3                                       0.04
# 4                                        NaN
#
# [5 rows x 96 columns]

# %%
# rename columns

# Renaming specific columns
rename_dict = {
    "Unnamed_1": "State",
    "Unnamed_2": "CoC_Name",
    "Unnamed_3": "CoC Number",
    "Unnamed_4": "CoC_Award_Amount",
    "Unnamed_5": "CoC_Category"
}
spm.rename(columns=rename_dict, inplace=True)

spm.head()
# Out:
#   State                                           CoC_Name CoC Number  \
# 0    AK                                      Anchorage CoC     AK-500
# 1    AK                        Alaska Balance of State CoC     AK-501
# 2    AL  Birmingham/Jefferson, St. Clair, Shelby Counti...     AL-500
# 3    AL            Mobile City & County/Baldwin County CoC     AL-501
# 4    AL                     Florence/Northwest Alabama CoC     AL-502
#
#    CoC_Award_Amount             CoC_Category  \
# 0         3756917.0  Other Largely Urban CoC
# 1          982016.0        Largely Rural CoC
# 2         9956635.0     Largely Suburban CoC
# 3         4056865.0  Other Largely Urban CoC
# 4          452202.0        Largely Rural CoC
#
#   Total Non-DV Beds on 2021 HIC ES+TH  \
# 0                                1185
# 1                                 518
# 2                                 602
# 3                                 309
# 4                                  56
#
#   Total Non-DV HMIS Beds on 2021 HIC ES+TH  \
# 0                                     1084
# 1                                      494
# 2                                      464
# 3                                      309
# 4                                        0
#
#   2021 Bed coverage Percent on HMIS for ES-TH Combined ES-SH Avg (Days)  \
# 0                                           0.914768                 59
# 1                                           0.953668                 48
# 2                                           0.770764                 56
# 3                                                  1                 35
# 4                                                  0                 49
#
#   ES-SH Median (Days)  ... HMIS DQ - ES Percent Unknown Destinations  \
# 0                  20  ...                                  0.831774
# 1                  19  ...                                  0.610868
# 2                  23  ...                                  0.089766
# 3                  11  ...                                  0.016168
# 4                  30  ...                                  0.042424
#
#   HMIS DQ Exits Universe - TH HMIS DQ Unknown Destinations - TH  \
# 0                         258                                49
# 1                         162                                15
# 2                         131                                 2
# 3                         142                                 3
# 4                           0                                 0
#
#   HMIS DQ - TH Percent Unknown Destinations HMIS DQ Exits Universe - RRH  \
# 0                                  0.189922                          860
# 1                                  0.092593                          196
# 2                                      0.02                          828
# 3                                      0.02                          205
# 4                                       NaN                          172
#
#   HMIS DQ Unknown Destinations - RRH  \
# 0                                138
# 1                                  5
# 2                                 40
# 3                                  5
# 4                                  0
#
#   HMIS DQ - RRH Percent Unknown Destinations HMIS DQ Exits Universe - PSH  \
# 0                                   0.160465                          108
# 1                                    0.02551                           35
# 2                                   0.048309                          252
# 3                                    0.02439                           27
# 4                                          0                            0
#
#   HMIS DQ Unknown Destinations - PSH  \
# 0                                  9
# 1                                  3
# 2                                  7
# 3                                  1
# 4                                  0
#
#   HMIS DQ - PSH Percent Unknown Destinations
# 0                                   0.083333
# 1                                   0.085714
# 2                                       0.03
# 3                                       0.04
# 4                                        NaN
#
# [5 rows x 96 columns]

# %% [markdown]
# ### spm dataset is now renamed ...Need to add parent column names over the column names

# %%
spm.shape
# Out:
# (388, 96)

# %% [markdown]
# ## Relation between funding and homeless ppl in HIMS:

# %%
#sns.scatterplot(data=spm, x='CoC_Award_Amount', y='Total HMIS Count', color='blue')

# %%
spm['State'].value_counts().head()
# Out:
# CA    44
# FL    27
# NY    24
# MI    20
# IL    19
# Name: State, dtype: int64
